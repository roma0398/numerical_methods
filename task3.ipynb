# %% [markdown]
# # АППРОКСИМАЦИЯ ФУНКЦИЙ

# %%
import numpy as np
import math
import matplotlib.pyplot as plt
from scipy.misc import derivative
from scipy import integrate

# %% [markdown]
# ### Объявление функции

# %%
def f(x):
    return x - (math.sin(x))

# %% [markdown]
# ### Строим матрицу $Q$

# %%
l = -1
r = 1
m = 3
n = 5
x = np.linspace(l, r, n)
y = np.array([f(i) for i in x])
Q = np.zeros((n, m + 1))
for i in range(n):
    for j in range(m + 1):
        Q[i][j] = x[i] ** j

# %% [markdown]
# ### Решаем систему $Ha=b$, где $H=Q^TQ, b=Q^Ty$

# %%
H = np.dot(Q.T, Q)
b = np.dot(Q.T, y)

a = np.linalg.solve(H, b)

# %% [markdown]
# #

# %% [markdown]
# #

# %% [markdown]
# #

# %% [markdown]
# ### Метод наименьших квадратов

# %%
def p1(x):
    res = 0
    for i in range(m + 1):
        res += a[i] * (x ** i)
    return res

# %% [markdown]
# ### Многочлен Лежандра

# %%
def L(n, x) :
    return 1/(math.factorial(n)*(2**n)) * derivative(lambda x : (1 - x**2)**n, x, dx=1e-3, n=n, order=11)

# %% [markdown]
# ### Коэффиценты $c_i$

# %%
def c(k):
    return integrate.quad(lambda x: f(x)*L(k, x), l, r)[0] / integrate.quad(lambda x: L(k, x)**2, l, r)[0]

# %% [markdown]
# ### Полином приближения в $L_2$

# %%
mm = 3
def p2(x):
    res = 0
    for i in range(mm + 1):
        res += c(i)*L(i, x)
    return res

# %% [markdown]
# #

# %% [markdown]
# #

# %% [markdown]
# #

# %% [markdown]
# #

# %% [markdown]
# ### График исходной функции

# %%
xg = np.arange(l, r + 0.1, 0.1)
yg = np.array([f(i) for i in xg])
plt.figure(figsize=(20, 20))
plt.grid(ls=':')
plt.xticks(np.arange(-1.25, 1.25, 0.25), fontsize=35)
plt.yticks(np.arange(-0.2, 0.2, 0.05), fontsize=35)
plt.plot(xg, yg, linewidth=8, color='k')
plt.show()

# %% [markdown]
# #

# %% [markdown]
# #

# %% [markdown]
# ### График полинома наилучшего приближения построенного по методу наименьших квадратов

# %%
xg = np.arange(l, r + 0.1, 0.1)
yg = np.array([p1(i) for i in xg])
plt.figure(figsize=(20, 20))
plt.grid(ls=':')
plt.xticks(np.arange(-1.25, 1.25, 0.25), fontsize=35)
plt.yticks(np.arange(-0.2, 0.2, 0.05), fontsize=35)
plt.plot(xg, yg, linewidth=8, color='k')
plt.show()

# %% [markdown]
# #

# %% [markdown]
# #

# %% [markdown]
# #

# %% [markdown]
# ### График полинома наилучшего приближения в пространстве $L_2$

# %%
xg = np.arange(l, r + 0.1, 0.1)
yg = np.array([p2(i) for i in xg])
plt.figure(figsize=(20, 20))
plt.grid(ls=':')
plt.xticks(np.arange(-1.25, 1.25, 0.25), fontsize=35)
plt.yticks(np.arange(-0.2, 0.2, 0.05), fontsize=35)
plt.plot(xg, yg, linewidth=8, color='k')
plt.show()
